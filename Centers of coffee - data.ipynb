# %% [markdown]
# # Centers of coffee - data

# %% [markdown]
# The data will be obtained by the foursquare API, I’ll be looking for geolocation data of all coffee shops and café’s in Rome, and I will be applying k-means algorithms to this data in order to find the locations that minimize the distance to all coffee shops and café’s.
#
# In this part I'll gather the data.

# %%
#importing pandas, numpy and relevant libraries
import pandas as pd
import numpy as np

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# import geocoder - a library for geolocation data
# !conda install -c conda-forge geocoder --yes 
import geocoder 
import time
import requests
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
#hiden cell
#Foursquare credentials

# %%
#using API to try get all coffe shops and cafe's
radius = 3500 # define radius
LIMIT = 1500 # limit of number of venues returned by Foursquare API
categoryId = "4bf58dd8d48988d16d941735,4bf58dd8d48988d1e0931735" #Cafe,coffe shop category ID in Foursquare API
location = "Rome"

# create URL

url = 'https://api.foursquare.com/v2/venues/explore?&categoryId={}&client_id={}&client_secret={}&v={}&near={}&radius={}&limit={}'.format(
    categoryId,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,
    location,
    radius, 
    LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e1c7de2542890001b22a9fd'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'geocode': {'what': '',
#    'where': 'rome',
#    'center': {'lat': 41.89193, 'lng': 12.51133},
#    'displayString': 'Rome, Latium, Italy',
#    'cc': 'IT',
#    'geometry': {'bounds': {'ne': {'lat': 41.98942097197372,
#       'lng': 12.615249866611695},
#      'sw': {'lat': 41.79461305370221, 'lng': 12.379309999999998}}},
#    'slug': 'roma',
#    'longId': '72057594041097006'},
#   'headerLocation': 'Rome',
#   'headerFullLocation': 'Rome',
#   'headerLocationGranularity': 'city',
#   'query': 'cafe',
#   'totalResults': 212,
#   'suggestedBounds': {'ne': {'lat': 41.92708938319744,
#     'lng': 12.560106323406826},
#    'sw': {'lat': 41.85587073838316, 'lng': 12.456626864462619}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbedfaafa8cee72738a5ef6',
#        'name': 'Bar Trani',
#        'location': {'address': 'Via Emanuele Filiberto, 8',
#         'crossStreet': 'Piazza Vittorio Emanuele',
#         'lat': 41.89303388899768,
#         'lng': 12.50534339915285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89303388899768,
#           'lng': 12.50534339915285}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Emanuele Filiberto, 8 (Piazza Vittorio Emanuele)',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbedfaafa8cee72738a5ef6-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5be2bed02d2fd9002c6f92d6',
#        'name': 'Molino',
#        'location': {'address': 'Via Merulana 282',
#         'lat': 41.896590381127275,
#         'lng': 12.499324553684346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.896590381127275,
#           'lng': 12.499324553684346}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Merulana 282',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5be2bed02d2fd9002c6f92d6-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54282873498e2d89dfdcaf0b',
#        'name': 'The British Corner',
#        'location': {'address': 'Via del Pigneto 112',
#         'lat': 41.888204385867624,
#         'lng': 12.531284537052292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.888204385867624,
#           'lng': 12.531284537052292}],
#         'cc': 'IT',
#         'country': 'Italia',
#         'formattedAddress': ['Via del Pigneto 112', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54282873498e2d89dfdcaf0b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c939b9d82b56dcb6149c7aa',
#        'name': 'Nespresso Boutique',
#        'location': {'address': 'Coin - Piazzale Appio, 7',
#         'lat': 41.885202774649585,
#         'lng': 12.509555812910266,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.885202774649585,
#           'lng': 12.509555812910266}],
#         'postalCode': '00173',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Coin - Piazzale Appio, 7',
#          '00173 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c939b9d82b56dcb6149c7aa-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d92e2759213b1f718b6bb46',
#        'name': 'Caffè Ciamei',
#        'location': {'address': 'Via Emanuele Filiberto, 57',
#         'crossStreet': 'Via Cairoli',
#         'lat': 41.89219253527157,
#         'lng': 12.50563980733279,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89219253527157,
#           'lng': 12.50563980733279}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Emanuele Filiberto, 57 (Via Cairoli)',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d92e2759213b1f718b6bb46-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdad2f964a520c65621e3',
#        'name': 'Panella',
#        'location': {'address': 'Via Merulana, 54',
#         'crossStreet': 'Largo Leopardi',
#         'lat': 41.894090013704094,
#         'lng': 12.500857095062907,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.894090013704094,
#           'lng': 12.500857095062907}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Merulana, 54 (Largo Leopardi)',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42628700'}},
#       'referralId': 'e-0-4adcdad2f964a520c65621e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf14977e9425481a65769c5',
#        'name': 'Fiorditè',
#        'location': {'address': 'Via Tuscolana, 30',
#         'lat': 41.88264,
#         'lng': 12.51579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88264,
#           'lng': 12.51579}],
#         'postalCode': '00182',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Tuscolana, 30',
#          '00182 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf14977e9425481a65769c5-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9364a452ed224bf04b1cac',
#        'name': 'La Licata',
#        'location': {'address': 'Via dei Serpenti 165',
#         'crossStreet': 'Via Leonina',
#         'lat': 41.89457933359971,
#         'lng': 12.490945109936206,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89457933359971,
#           'lng': 12.490945109936206}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via dei Serpenti 165 (Via Leonina)',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '59338393'}},
#       'referralId': 'e-0-4d9364a452ed224bf04b1cac-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d05f50554d0236af9c9f6d5',
#        'name': 'Bar Ornelli',
#        'location': {'lat': 41.892662,
#         'lng': 12.501427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.892662,
#           'lng': 12.501427}],
#         'cc': 'IT',
#         'country': 'Italia',
#         'formattedAddress': ['Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d05f50554d0236af9c9f6d5-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58776aef92789f77db77e1db',
#        'name': 'Faro',
#        'location': {'address': 'Via Piave 55',
#         'lat': 41.91036279919297,
#         'lng': 12.498212681898742,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.91036279919297,
#           'lng': 12.498212681898742}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Piave 55', 'Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58776aef92789f77db77e1db-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c948d48f7cfa1cdc1cdb415',
#        'name': "Pasticceria d'Amore",
#        'location': {'address': 'Via dello Statuto, 37/A/B',
#         'lat': 41.89498997858735,
#         'lng': 12.500729829862271,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89498997858735,
#           'lng': 12.500729829862271}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via dello Statuto, 37/A/B',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c948d48f7cfa1cdc1cdb415-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523eac2911d26f5ff74ace68',
#        'name': 'La Casetta',
#        'location': {'address': 'Via Madonna Dei Monti 62',
#         'lat': 41.8944136065404,
#         'lng': 12.490324021652178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.8944136065404,
#           'lng': 12.490324021652178}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Madonna Dei Monti 62',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523eac2911d26f5ff74ace68-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c94bfc5533aa093bbf7c145',
#        'name': "Caffè Tazza D'Oro",
#        'location': {'address': 'Via del Tritone,  45',
#         'lat': 41.90230253782284,
#         'lng': 12.483559761326038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90230253782284,
#           'lng': 12.483559761326038}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via del Tritone,  45',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c94bfc5533aa093bbf7c145-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51768972e4b090f99a3a28dc',
#        'name': 'Illy Shop',
#        'location': {'address': 'Via Dei Due Macelli 59/D',
#         'lat': 41.90447165903796,
#         'lng': 12.48356673905414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90447165903796,
#           'lng': 12.48356673905414}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Dei Due Macelli 59/D',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51768972e4b090f99a3a28dc-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdac4f964a5208a5221e3',
#        'name': "Tazza d'Oro",
#        'location': {'address': 'Via degli Orfani, 84',
#         'lat': 41.89943500478219,
#         'lng': 12.477359207618287,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89943500478219,
#           'lng': 12.477359207618287}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'neighborhood': "Sant'Eustachio",
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via degli Orfani, 84',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdac4f964a5208a5221e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57bc0da7cd10acb18f13a12f',
#        'name': "d'angelo bar",
#        'location': {'address': 'Via 20 settembre',
#         'lat': 41.90548017202705,
#         'lng': 12.49572521836807,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90548017202705,
#           'lng': 12.49572521836807}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via 20 settembre', 'Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57bc0da7cd10acb18f13a12f-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569ce053498e49ebb4008aa8',
#        'name': 'Roscioli CAFFè - pasticceria',
#        'location': {'address': 'Piazza Benedetto Cairoli, 16',
#         'lat': 41.894206258050566,
#         'lng': 12.474553676709009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.894206258050566,
#           'lng': 12.474553676709009}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza Benedetto Cairoli, 16',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569ce053498e49ebb4008aa8-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d99a9e10caaa1431a65c9b3',
#        'name': 'Pretorius Cafè',
#        'location': {'address': 'Via San Martino della Battaglia, 27',
#         'crossStreet': 'Viale Castro Pretorio',
#         'lat': 41.905886846840254,
#         'lng': 12.50494684305828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.905886846840254,
#           'lng': 12.50494684305828}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via San Martino della Battaglia, 27 (Viale Castro Pretorio)',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d99a9e10caaa1431a65c9b3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce15a33aba88cfa09c054d7',
#        'name': 'Er Caffettiere',
#        'location': {'address': 'Piazza della Suburra 1',
#         'lat': 41.894920080758794,
#         'lng': 12.493028259508987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.894920080758794,
#           'lng': 12.493028259508987}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza della Suburra 1',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce15a33aba88cfa09c054d7-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7a9d26f964a52093332fe3',
#        'name': 'Caffè Barberini',
#        'location': {'address': 'Via Marmorata, 41',
#         'lat': 41.878968332633406,
#         'lng': 12.478881628514717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.878968332633406,
#           'lng': 12.478881628514717}],
#         'postalCode': '00153',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Marmorata, 41',
#          '00153 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7a9d26f964a52093332fe3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdac2f964a520165221e3',
#        'name': 'Antico Caffè Greco',
#        'location': {'address': 'Via dei Condotti, 84',
#         'lat': 41.90557515777896,
#         'lng': 12.481655805734745,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90557515777896,
#           'lng': 12.481655805734745}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via dei Condotti, 84',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85482156'}},
#       'referralId': 'e-0-4adcdac2f964a520165221e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51cace42498eb06f107ca80e',
#        'name': 'La Casa Del Cafe',
#        'location': {'address': 'via degli Orfani 84',
#         'lat': 41.89939827116926,
#         'lng': 12.477389574050903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89939827116926,
#           'lng': 12.477389574050903}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['via degli Orfani 84',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51cace42498eb06f107ca80e-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbb84013de8c9b6f0d899ad',
#        'name': 'Barnum Cafè',
#        'location': {'address': 'Via del Pellegrino 87',
#         'lat': 41.897079,
#         'lng': 12.469898,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.897079,
#           'lng': 12.469898}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'neighborhood': 'Regola',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via del Pellegrino 87',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbb84013de8c9b6f0d899ad-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5810782138fa62276ec9ac49',
#        'name': '404 name not found',
#        'location': {'address': 'Via Santa Cecilia, 1',
#         'crossStreet': 'Via Dei Vascella',
#         'lat': 41.88759535590742,
#         'lng': 12.477177679538725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88759535590742,
#           'lng': 12.477177679538725}],
#         'postalCode': '00153',
#         'cc': 'IT',
#         'neighborhood': 'Trastevere',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Santa Cecilia, 1 (Via Dei Vascella)',
#          '00153 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5810782138fa62276ec9ac49-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5688f88e498e725a3bf79ca2',
#        'name': 'Il Gianfornaio',
#        'location': {'address': 'Via Marmorata',
#         'lat': 41.88179749006553,
#         'lng': 12.47682103745769,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88179749006553,
#           'lng': 12.47682103745769}],
#         'postalCode': '00153',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Marmorata', '00153 Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5688f88e498e725a3bf79ca2-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbdb92d4b222080d3b07b4f',
#        'name': 'Bar Viminale',
#        'location': {'address': 'Via del Viminale 45',
#         'crossStreet': 'Via Agostino Depretis',
#         'lat': 41.89977027703517,
#         'lng': 12.49507777999772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89977027703517,
#           'lng': 12.49507777999772}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via del Viminale 45 (Via Agostino Depretis)',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbdb92d4b222080d3b07b4f-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdac2f964a520095221e3',
#        'name': "Babington's Tea Room",
#        'location': {'address': 'Piazza di Spagna 23',
#         'lat': 41.90593916858777,
#         'lng': 12.482230785764775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90593916858777,
#           'lng': 12.482230785764775}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza di Spagna 23',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdac2f964a520095221e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af867d8f964a520f10c22e3',
#        'name': "Sant'Eustachio Il Caffè",
#        'location': {'address': "Piazza di Sant'Eustachio, 82",
#         'crossStreet': 'Via della Dogana Vecchia',
#         'lat': 41.89827,
#         'lng': 12.475379,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89827,
#           'lng': 12.475379}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'neighborhood': "Sant'Eustachio",
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ["Piazza di Sant'Eustachio, 82 (Via della Dogana Vecchia)",
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af867d8f964a520f10c22e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdac3f964a520695221e3',
#        'name': 'Ciampini',
#        'location': {'address': 'Piazza di San Lorenzo in Lucina, 29',
#         'lat': 41.90364057578211,
#         'lng': 12.478072152890318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90364057578211,
#           'lng': 12.478072152890318}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza di San Lorenzo in Lucina, 29',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcdac3f964a520695221e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1f338c887799f23ff66b68',
#        'name': 'Simon Bar',
#        'location': {'address': 'Via di Santa Maria Maggiore, 182-183',
#         'crossStreet': 'Via Urbana',
#         'lat': 41.89721956645133,
#         'lng': 12.494986471868307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89721956645133,
#           'lng': 12.494986471868307}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via di Santa Maria Maggiore, 182-183 (Via Urbana)',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1f338c887799f23ff66b68-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc02f21abf49521abfbbe93',
#        'name': 'VyTA Boulangerie Italiana',
#        'location': {'address': 'Stazione Roma Termini, Via Marsala, Edificio D',
#         'crossStreet': 'piano binari',
#         'lat': 41.90179852382263,
#         'lng': 12.502609953587411,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90179852382263,
#           'lng': 12.502609953587411}],
#         'postalCode': '00185',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Stazione Roma Termini, Via Marsala, Edificio D (piano binari)',
#          '00185 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc02f21abf49521abfbbe93-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5779959e498eb9d101e4374b',
#        'name': 'Osteria Circo',
#        'location': {'lat': 41.88775284209845,
#         'lng': 12.484217321543731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88775284209845,
#           'lng': 12.484217321543731}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['00186 Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5779959e498eb9d101e4374b-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beb9090a9900f474d051840',
#        'name': 'Valentini',
#        'location': {'address': 'Piazza Tuscolo, 2',
#         'lat': 41.880548655681075,
#         'lng': 12.508525057575373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.880548655681075,
#           'lng': 12.508525057575373}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza Tuscolo, 2', 'Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beb9090a9900f474d051840-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1c7ac5fcf8c9b68a32aa0b',
#        'name': 'Bar del Cappuccino',
#        'location': {'address': 'Via Arenula 50',
#         'lat': 41.89219252834642,
#         'lng': 12.474715684747165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89219252834642,
#           'lng': 12.474715684747165}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Arenula 50', '00186 Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1c7ac5fcf8c9b68a32aa0b-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c73272e4b0e9cee7389b7b',
#        'name': 'Espressamente Illy',
#        'location': {'address': 'Via Uffici Del Vicario 31/32',
#         'lat': 41.90104874248111,
#         'lng': 12.477579894509063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90104874248111,
#           'lng': 12.477579894509063}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Uffici Del Vicario 31/32',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c73272e4b0e9cee7389b7b-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d306437a62d721e12dc997d',
#        'name': 'Bompiani Bar Gelateria Pasticceria',
#        'location': {'lat': 41.85910794951108,
#         'lng': 12.502292491521326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.85910794951108,
#           'lng': 12.502292491521326}],
#         'cc': 'IT',
#         'country': 'Italia',
#         'formattedAddress': ['Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4d306437a62d721e12dc997d-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556844a4498e9ef9bd19f0b3',
#        'name': 'Caffè Monti',
#        'location': {'address': 'via G. Lanza, 132',
#         'crossStreet': 'p-za S. Martino ai Monti',
#         'lat': 41.895018159604795,
#         'lng': 12.498316047957392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.895018159604795,
#           'lng': 12.498316047957392}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['via G. Lanza, 132 (p-za S. Martino ai Monti)',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-556844a4498e9ef9bd19f0b3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdd877cea279c74cc41e22b',
#        'name': 'Caffè Capitolino',
#        'location': {'address': 'Piazza Caffarelli 4',
#         'lat': 41.892583529889706,
#         'lng': 12.481725432601586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.892583529889706,
#           'lng': 12.481725432601586}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza Caffarelli 4',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdd877cea279c74cc41e22b-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b84ea8ef964a5207c4731e3',
#        'name': "L'Emporio alla Pace",
#        'location': {'address': 'Via di Tor Millina 28',
#         'crossStreet': 'Via della Pace',
#         'lat': 41.8992898644914,
#         'lng': 12.47124335244163,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.8992898644914,
#           'lng': 12.47124335244163}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via di Tor Millina 28 (Via della Pace)',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b84ea8ef964a5207c4731e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3a4bf0e4b03d32df800b11',
#        'name': 'Bar Lillo',
#        'location': {'address': 'Via dei Genovesi 39',
#         'lat': 41.88766217375497,
#         'lng': 12.477157785963435,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88766217375497,
#           'lng': 12.477157785963435}],
#         'postalCode': '00153',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via dei Genovesi 39',
#          '00153 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3a4bf0e4b03d32df800b11-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e05cbe11838eb15aef63f25',
#        'name': 'Cafė Trevi',
#        'location': {'address': 'Piazza Fontana di Trevi, 90',
#         'lat': 41.90069241727797,
#         'lng': 12.482983334958622,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90069241727797,
#           'lng': 12.482983334958622}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza Fontana di Trevi, 90',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e05cbe11838eb15aef63f25-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6fd469df6b8cfa6535b64d',
#        'name': 'Bar Frattina',
#        'location': {'address': 'Via Frattina, 142',
#         'crossStreet': 'via Mario de Fiori',
#         'lat': 41.90453,
#         'lng': 12.48233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90453,
#           'lng': 12.48233}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Frattina, 142 (via Mario de Fiori)',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
# ...
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '530084ad498e9c0822380172',
#        'name': 'Gima Caffe',
#        'location': {'address': "Piazza Dell' Esquilino 35-36",
#         'lat': 41.89843937919868,
#         'lng': 12.496697045478705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89843937919868,
#           'lng': 12.496697045478705}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ["Piazza Dell' Esquilino 35-36",
#          'Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-530084ad498e9c0822380172-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3dad5614aa8cfaeac9b55e',
#        'name': 'Amelie',
#        'location': {'address': 'Piazza Verbano, 17',
#         'lat': 41.923574339065155,
#         'lng': 12.507057062068561,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.923574339065155,
#           'lng': 12.507057062068561}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza Verbano, 17', 'Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4d3dad5614aa8cfaeac9b55e-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5381f408498ea82192d6192f',
#        'name': 'Monti',
#        'location': {'address': 'Via Urbana, 93',
#         'crossStreet': 'Via dei Ciancaleoni',
#         'lat': 41.89575,
#         'lng': 12.49362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89575,
#           'lng': 12.49362}],
#         'postalCode': '00184',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Urbana, 93 (Via dei Ciancaleoni)',
#          '00184 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '140240900'}},
#       'referralId': 'e-0-5381f408498ea82192d6192f-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7caed8ad90224b3cee8a0c',
#        'name': 'Antico Caffè del Teatro Marcello',
#        'location': {'address': 'Via del Teatro Marcello 42',
#         'crossStreet': 'Via Montanara',
#         'lat': 41.89270359328462,
#         'lng': 12.480318685419936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89270359328462,
#           'lng': 12.480318685419936}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via del Teatro Marcello 42 (Via Montanara)',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7caed8ad90224b3cee8a0c-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcdac2f964a520195221e3',
#        'name': 'Il Cigno',
#        'location': {'address': '16 Viale Parioli',
#         'lat': 41.92385217206952,
#         'lng': 12.490833502129005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.92385217206952,
#           'lng': 12.490833502129005}],
#         'postalCode': '00197',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['16 Viale Parioli',
#          '00197 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4adcdac2f964a520195221e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e898f8d5c5c64ed49bc35a4',
#        'name': 'Abitudini & Follie',
#        'location': {'address': 'Via Pavia 24',
#         'lat': 41.907994994879544,
#         'lng': 12.516890395001873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.907994994879544,
#           'lng': 12.516890395001873}],
#         'postalCode': '00161',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Pavia 24', '00161 Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e898f8d5c5c64ed49bc35a4-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca3653ea73cb60c085f1878',
#        'name': 'Gran Caffè Roma',
#        'location': {'address': "Piazza d'Aracoeli 4",
#         'crossStreet': "Via della Tribuna di Tor de' Specchi",
#         'lat': 41.89413307268742,
#         'lng': 12.481310567047286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.89413307268742,
#           'lng': 12.481310567047286}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ["Piazza d'Aracoeli 4 (Via della Tribuna di Tor de' Specchi)",
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca3653ea73cb60c085f1878-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb063c1f964a5208d433ce3',
#        'name': 'Bar Benaco',
#        'location': {'address': 'Via Benaco, 13',
#         'crossStreet': 'Via Di Villa Ada',
#         'lat': 41.92377723268971,
#         'lng': 12.505974590249513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.92377723268971,
#           'lng': 12.505974590249513}],
#         'postalCode': '00198',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Benaco, 13 (Via Di Villa Ada)',
#          '00198 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4bb063c1f964a5208d433ce3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d28c35498e52d924cdb8f7',
#        'name': 'Caffetteria Chiostro del Bramante',
#        'location': {'address': 'Arco della Pace, 5',
#         'crossStreet': 'Chiostro del Bramante',
#         'lat': 41.900048325250545,
#         'lng': 12.471514616073867,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.900048325250545,
#           'lng': 12.471514616073867}],
#         'postalCode': '00186',
#         'cc': 'IT',
#         'neighborhood': 'Ponte',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Arco della Pace, 5 (Chiostro del Bramante)',
#          '00186 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52d28c35498e52d924cdb8f7-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '558bcd80498eb8fa9df510b7',
#        'name': 'Vero Food',
#        'location': {'address': 'Via XX Settembre',
#         'lat': 41.90552421114724,
#         'lng': 12.495841201418385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90552421114724,
#           'lng': 12.495841201418385}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via XX Settembre', 'Roma Lazio', 'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-558bcd80498eb8fa9df510b7-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba9d978f964a520903a3ae3',
#        'name': 'Caffè Piccarozzi',
#        'location': {'address': 'Piazza della Repubblica 62',
#         'lat': 41.90266066735817,
#         'lng': 12.495786504130951,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90266066735817,
#           'lng': 12.495786504130951}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Piazza della Repubblica 62',
#          'Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba9d978f964a520903a3ae3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51666f57e4b00227201c646b',
#        'name': 'Sali & Tabacchi',
#        'location': {'address': 'Via Di Campo Marzio 47',
#         'lat': 41.90286485575406,
#         'lng': 12.477721967228334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.90286485575406,
#           'lng': 12.477721967228334}],
#         'postalCode': '00187',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Di Campo Marzio 47',
#          '00187 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51666f57e4b00227201c646b-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50826ffde4b0ee1f0ecbcbc8',
#        'name': 'Caffè Negresco',
#        'location': {'address': 'Via della Piramide Cestia, 35',
#         'lat': 41.88852675217771,
#         'lng': 12.49386944645606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.88852675217771,
#           'lng': 12.49386944645606}],
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via della Piramide Cestia, 35',
#          'Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50826ffde4b0ee1f0ecbcbc8-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c448f7edd1f2d7f530680f9',
#        'name': 'Nespresso Boutique',
#        'location': {'address': 'Via Cola di Rienzo, 173',
#         'crossStreet': 'COIN',
#         'lat': 41.908109839118374,
#         'lng': 12.464120356396378,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.908109839118374,
#           'lng': 12.464120356396378}],
#         'postalCode': '00193',
#         'cc': 'IT',
#         'city': 'Roma',
#         'state': 'Lazio',
#         'country': 'Italia',
#         'formattedAddress': ['Via Cola di Rienzo, 173 (COIN)',
#          '00193 Roma Lazio',
#          'Italia']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c448f7edd1f2d7f530680f9-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#making a data frame 
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # normalize JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                  name   categories        lat        lng
# 0           Bar Trani         Café  41.893034  12.505343
# 1              Molino         Café  41.896590  12.499325
# 2  The British Corner     Tea Room  41.888204  12.531285
# 3  Nespresso Boutique  Coffee Shop  41.885203  12.509556
# 4        Caffè Ciamei         Café  41.892193  12.505640

# %%
#looking at the veneus
Location = [41.9, 12.5]
map_cafe = folium.Map(location=Location, zoom_start=11)

# add markers to map
for lat, lng, name in zip(nearby_venues['lat'],
                          nearby_venues['lng'],
                          nearby_venues['name']):
    label = name
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cafe) 
map_cafe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looks like we are not getting all of Rome

# %%
nearby_venues.shape
# Out:
# (100, 4)

# %% [markdown]
# Only 100 venues, not 1500 like the limit I stated. Foursquare API only returns up to 100 in a querie. I think I need multiple queries in order to get all of them.

# %% [markdown]
# I'll build a grid to run multiple searches and then merge the results

# %%
grid = [(i/50 - 0.1 ,j/50 - 0.1) for i in range(11) for j in range(11)]

# %%
#looking at the veneus
Location = [41.9, 12.5]
map_cafe = folium.Map(location=Location, zoom_start=11)

# add markers to map
for ll in grid:
    label = "name"
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Location[0] + ll[0], Location[1] + ll[1]],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cafe) 
map_cafe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The grid covers rome like i wanted. Now I'll run multyple surches in Foursquare to get all the coffe shops of rome

# %%
#using API to get all coffe shops and cafe's
radius = 3500 # define radius
LIMIT = 500 # limit of number of venues returned by Foursquare API
categoryId = "4bf58dd8d48988d16d941735,4bf58dd8d48988d1e0931735" #Cafe,coffe shop category ID in Foursquare API
location = "Rome"
df = pd.DataFrame(columns =  ['name', 'categories', 'lat', 'lng'])

# create URL
for ll in grid:
    url = 'https://api.foursquare.com/v2/venues/explore?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        categoryId,
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION,
        ll[0] + 41.9,
        ll[1] + 12.5,
        radius, 
        LIMIT)
    results = requests.get(url).json()
    #time.sleep(1)

    #making a data frame 
    venues = results['response']['groups'][0]['items']

    nearby_venues = json_normalize(venues) # normalize JSON
    
    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    if 'venue.name' in nearby_venues.columns:
        nearby_venues =nearby_venues.loc[:, filtered_columns]

        # filter the category for each row
        nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

        # clean columns
        nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
        df = pd.merge(df, nearby_venues, on= ['name', 'categories', 'lat', 'lng'],how='outer')


df.head()
# Out:
#                                   name categories        lat        lng
# 0                   Bar Dal Pannocchia       Café  41.796270  12.407022
# 1                           Mondo Gelo       Café  41.783271  12.435756
# 2                              BarCode       Café  41.796178  12.432368
# 3                           Bar Bucchi       Café  41.786176  12.383650
# 4  Red Cafe At Un World Food Programme       Café  41.821181  12.408381

# %%
#looking at the veneus
Location = [41.9, 12.5]
map_cafe = folium.Map(location=Location, zoom_start=11)

# add markers to map
for lat, lng, name in zip(df['lat'],
                          df['lng'],
                          df['name']):
    label = name
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cafe) 
map_cafe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Good! we have all the data, next part will be to apply k-means to this data, this belongs in next weeks assinment
